# %% [markdown]
# ## OpenCV ile Şekil Çizme Alıştırması

# %% [markdown]
# ---

# %% [markdown]
# ### Aşağıdaki görevleri belirtilen ipuçlarıyla birlikte çözünüz.

# %% [markdown]
# **Görev :** Daha önceki derslerde kullandığımız yada sizin seçeceğiniz bir adet resmi notebook ekranınızda gösterniz. RGB sıralamasından lütfen emin olunuz.

# %%
# Gerekli kütüphanelerin içeri aktarılması

# %%
# Resmin okunması

# %%
# Resmin ekrana bastırılması

# %%
# Resimin RGB moduna dönüştürülmesi

# Resimin tekrar notebook ekranına bastırılması

# %% [markdown]
# **Görev :** Resimimize ters çevirme işlemi uygulayınız ve notebook ekranına bastırınız. ( Resiminizin bir adet kopyasını oluşturarak devam edebilirsiniz )

# %%
# Resimi kopyalama

# %%
# Resimin ters döndürülmesi

# Resmin Ekrana Basılması

# %% [markdown]
# **Görev :** Köpek resimimizin yüzüne denk gelecek şekilde kare çiziniz.

# %%
# Kare çizilmesi

# Ekrana Basılması

# %% [markdown]
# **Görev :** Köpeğin yüzünün ortasına bir adet üçgen çiziniz. Boyut oranını siz ayarlayınız.

# %%
# Out:
# array([[ 600,  400],
#        [ 850,    0],
#        [1100,  400]])

# %%
# Out:
# (3, 2)

# %% [markdown]
# **Ekstra Görev :** Yukarıda çizdiğimiz üçgenin içini doldurunuz. Bunun için küçük bir araştırma yapmalısınız !

# %% [markdown]
# **Görev :** Mouse'a her sol tıkladığımızda daire çizen kodu yazınız.

# %%
# Kütüphanelerin içeri aktarılması


# Daire oluşturan fonksiyon

        
# Resimi okuma, ekrana isim verme,mouse hareketini çağırma 


#Resmin görüntülenme işlemi

# %% [markdown]
# ### TEBRİKLER BÖLÜM SONU ALIŞTIRMASINI BAŞARIYLA TAMAMLADINIZ
